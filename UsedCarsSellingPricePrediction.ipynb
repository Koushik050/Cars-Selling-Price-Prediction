# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r"C:\Users\bittu\Desktop\Mini Project files\Book1.xlsx")

# %%
df
# Out:
#            car_name     insurance_validity fuel_type  seats  kms_driven  \
# 1     Mercedes-Benz          Comprehensive    Petrol      5       56000
# 2            Nissan          Comprehensive    Petrol      5       30615
# 3               BMW          Comprehensive    Diesel      5       24000
# 4               Kia          Comprehensive    Petrol      5       18378
# 5             Skoda          Comprehensive    Petrol      5       44900
# ...             ...                    ...       ...    ...         ...
# 1549        Hyundai          Comprehensive    Diesel      5       35000
# 1550        Renault  Third Party insurance    Petrol      5       10000
# 1551          Honda          Comprehensive    Petrol      5       49000
# 1552     Volkswagen          Comprehensive    Petrol      5       40000
# 1553         Maruti          Comprehensive    Petrol      5       34756
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1      First Owner    Automatic               2017           7.81      2996.0
# 2      First Owner    Automatic               2020          17.40       999.0
# 3      First Owner    Automatic               2018          20.68      1995.0
# 4      First Owner       Manual               2019          16.50      1353.0
# 5      First Owner    Automatic               2019          14.67      1798.0
# ...            ...          ...                ...            ...         ...
# 1549   First Owner    Automatic               2020        1493.00     11345.0
# 1550        999 cc         2022     Power Steering         999.00      6706.0
# 1551   First Owner       Manual               2017          17.50      1199.0
# 1552  Second Owner       Manual               2018          18.78       999.0
# 1553   First Owner       Manual               2018          20.85      1197.0
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)
# 1             2996.0       333.0            63.75
# 2              999.0      9863.0             8.99
# 3             1995.0       188.0            23.75
# 4             1353.0     13808.0            13.56
# 5             1798.0     17746.0            24.00
# ...              ...         ...              ...
# 1549         11345.0       250.0            17.41
# 1550          6706.0        91.0             3.98
# 1551          1199.0       887.0             5.85
# 1552           999.0        75.0             4.75
# 1553          1197.0      8314.0             6.10
#
# [1132 rows x 13 columns]

# %%
df.drop(columns='index',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.drop(columns='index',inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
df.index=np.arange(1,len(df)+1)

# %%
df
# Out:
#            car_name     insurance_validity fuel_type  seats  kms_driven  \
# 1     Mercedes-Benz          Comprehensive    Petrol      5       56000
# 2            Nissan          Comprehensive    Petrol      5       30615
# 3               BMW          Comprehensive    Diesel      5       24000
# 4               Kia          Comprehensive    Petrol      5       18378
# 5             Skoda          Comprehensive    Petrol      5       44900
# ...             ...                    ...       ...    ...         ...
# 1549        Hyundai          Comprehensive    Diesel      5       35000
# 1550        Renault  Third Party insurance    Petrol      5       10000
# 1551          Honda          Comprehensive    Petrol      5       49000
# 1552     Volkswagen          Comprehensive    Petrol      5       40000
# 1553         Maruti          Comprehensive    Petrol      5       34756
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1      First Owner    Automatic               2017           7.81      2996.0
# 2      First Owner    Automatic               2020          17.40       999.0
# 3      First Owner    Automatic               2018          20.68      1995.0
# 4      First Owner       Manual               2019          16.50      1353.0
# 5      First Owner    Automatic               2019          14.67      1798.0
# ...            ...          ...                ...            ...         ...
# 1549   First Owner    Automatic               2020        1493.00     11345.0
# 1550        999 cc         2022     Power Steering         999.00      6706.0
# 1551   First Owner       Manual               2017          17.50      1199.0
# 1552  Second Owner       Manual               2018          18.78       999.0
# 1553   First Owner       Manual               2018          20.85      1197.0
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)
# 1             2996.0       333.0            63.75
# 2              999.0      9863.0             8.99
# 3             1995.0       188.0            23.75
# 4             1353.0     13808.0            13.56
# 5             1798.0     17746.0            24.00
# ...              ...         ...              ...
# 1549         11345.0       250.0            17.41
# 1550          6706.0        91.0             3.98
# 1551          1199.0       887.0             5.85
# 1552           999.0        75.0             4.75
# 1553          1197.0      8314.0             6.10
#
# [1132 rows x 13 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1132, 13)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# car_name              0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         0
# engine(cc)            0
# max_power(bhp)        0
# torque(Nm)            0
# price(in lakhs)       0
# dtype: int64

# %%
df['car_name']=df['car_name'].replace('Lexus','Nexus')

# %%
df['car_name'].value_counts()
# Out:
# car_name
# Maruti           254
# Hyundai          240
# Honda            130
# Mercedes-Benz     97
# BMW               60
# Toyota            46
# Audi              40
# Tata              38
# Mahindra          33
# Ford              25
# Volkswagen        22
# Kia               22
# Renault           21
# Nissan            17
# Land              14
# MG                14
# Skoda             11
# Jeep              11
# Volvo             10
# Jaguar             6
# Datsun             4
# Mitsubishi         3
# Nexus              3
# Isuzu              2
# Porsche            2
# Mini               2
# Fiat               1
# Lamborghini        1
# Name: count, dtype: int64

# %%
df['insurance_validity']=df['insurance_validity'].replace('Third Party','Third Party insurance')
df['insurance_validity']=df['insurance_validity'].replace('Zero Dep','Third Party insurance')
df['insurance_validity']=df['insurance_validity'].replace('Not Available','')
df['insurance_validity']=df['insurance_validity'].replace('Petrol','')
a=['']
b=df[df['insurance_validity'].isin(a)].index
df.drop(b,inplace=True)

# %%
df['insurance_validity']=df['insurance_validity'].replace('Comprehensive','Yes')
df['insurance_validity']=df['insurance_validity'].replace('Third Party insurance','No')

# %%
dfle=df

# %%
df=df.sort_values(by='price(in lakhs)')

# %%
df
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1109           Fiat                 No    Diesel      5       80000
# 1300        Porsche                 No    Petrol      5        5700
# 917   Mercedes-Benz                 No    Diesel      7       46001
# 464   Mercedes-Benz                Yes    Petrol      4       40000
# 1464  Mercedes-Benz                Yes    Diesel      7       34987
# ...             ...                ...       ...    ...         ...
# 480             BMW                Yes    Diesel      7       44000
# 221   Mercedes-Benz                Yes    Petrol      4       50000
# 1493            BMW                Yes    Petrol      7       28000
# 174            Ford                Yes    Petrol      5       66717
# 1278         Maruti                Yes    Petrol      5       44002
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  \
# 1109   Third Owner       Manual               2010          20.30
# 1300   First Owner    Automatic               2019        2995.00
# 917    First Owner    Automatic               2021        2925.00
# 464    First Owner    Automatic               2018           7.81
# 1464   First Owner    Automatic               2020        2925.00
# ...            ...          ...                ...            ...
# 480    First Owner    Automatic               2020          13.38
# 221    First Owner    Automatic               2016           7.81
# 1493   First Owner    Automatic               2019          10.54
# 174   Second Owner       Manual               2011        1196.00
# 1278   Third Owner       Manual               2009          19.70
#
#         engine(cc)  max_power(bhp)  torque(Nm)  price(in lakhs)
# 1109  1.248000e+03    1.248000e+03        75.0             1.00
# 1300  3.400000e+02    3.400000e+02       450.0             1.05
# 917   3.258640e+12    3.258640e+12       700.0             1.06
# 464   4.663000e+03    4.663000e+03       459.0             1.09
# 1464  3.258640e+12    3.258640e+12       700.0             1.10
# ...            ...             ...         ...              ...
# 480   2.993000e+03    2.993000e+03     26150.0            98.50
# 221   4.663000e+03    4.663000e+03       459.0            98.50
# 1493  2.998000e+03    2.998000e+03     33525.0            99.00
# 174   7.000000e+01    7.000000e+01       102.0         70000.00
# 1278  7.960000e+02    7.960000e+02       463.0         95000.00
#
# [1127 rows x 13 columns]

# %%
dfle
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1     Mercedes-Benz                Yes    Petrol      5       56000
# 2            Nissan                Yes    Petrol      5       30615
# 3               BMW                Yes    Diesel      5       24000
# 4               Kia                Yes    Petrol      5       18378
# 5             Skoda                Yes    Petrol      5       44900
# ...             ...                ...       ...    ...         ...
# 1549        Hyundai                Yes    Diesel      5       35000
# 1550        Renault                 No    Petrol      5       10000
# 1551          Honda                Yes    Petrol      5       49000
# 1552     Volkswagen                Yes    Petrol      5       40000
# 1553         Maruti                Yes    Petrol      5       34756
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1      First Owner    Automatic               2017           7.81      2996.0
# 2      First Owner    Automatic               2020          17.40       999.0
# 3      First Owner    Automatic               2018          20.68      1995.0
# 4      First Owner       Manual               2019          16.50      1353.0
# 5      First Owner    Automatic               2019          14.67      1798.0
# ...            ...          ...                ...            ...         ...
# 1549   First Owner    Automatic               2020        1493.00     11345.0
# 1550        999 cc         2022     Power Steering         999.00      6706.0
# 1551   First Owner       Manual               2017          17.50      1199.0
# 1552  Second Owner       Manual               2018          18.78       999.0
# 1553   First Owner       Manual               2018          20.85      1197.0
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)
# 1             2996.0       333.0            63.75
# 2              999.0      9863.0             8.99
# 3             1995.0       188.0            23.75
# 4             1353.0     13808.0            13.56
# 5             1798.0     17746.0            24.00
# ...              ...         ...              ...
# 1549         11345.0       250.0            17.41
# 1550          6706.0        91.0             3.98
# 1551          1199.0       887.0             5.85
# 1552           999.0        75.0             4.75
# 1553          1197.0      8314.0             6.10
#
# [1127 rows x 13 columns]

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1109           Fiat                 No    Diesel      5       80000
# 1300        Porsche                 No    Petrol      5        5700
# 917   Mercedes-Benz                 No    Diesel      7       46001
# 464   Mercedes-Benz                Yes    Petrol      4       40000
# 1464  Mercedes-Benz                Yes    Diesel      7       34987
# ...             ...                ...       ...    ...         ...
# 480             BMW                Yes    Diesel      7       44000
# 221   Mercedes-Benz                Yes    Petrol      4       50000
# 1493            BMW                Yes    Petrol      7       28000
# 174            Ford                Yes    Petrol      5       66717
# 1278         Maruti                Yes    Petrol      5       44002
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  \
# 1109   Third Owner       Manual               2010          20.30
# 1300   First Owner    Automatic               2019        2995.00
# 917    First Owner    Automatic               2021        2925.00
# 464    First Owner    Automatic               2018           7.81
# 1464   First Owner    Automatic               2020        2925.00
# ...            ...          ...                ...            ...
# 480    First Owner    Automatic               2020          13.38
# 221    First Owner    Automatic               2016           7.81
# 1493   First Owner    Automatic               2019          10.54
# 174   Second Owner       Manual               2011        1196.00
# 1278   Third Owner       Manual               2009          19.70
#
#            engine(cc)   max_power(bhp)  torque(Nm)  price(in lakhs)
# 1109          1248.00          1248.00       75.00             1.00
# 1300           340.00           340.00      450.00             1.05
# 917  3258640000000.00 3258640000000.00      700.00             1.06
# 464           4663.00          4663.00      459.00             1.09
# 1464 3258640000000.00 3258640000000.00      700.00             1.10
# ...               ...              ...         ...              ...
# 480           2993.00          2993.00    26150.00            98.50
# 221           4663.00          4663.00      459.00            98.50
# 1493          2998.00          2998.00    33525.00            99.00
# 174             70.00            70.00      102.00         70000.00
# 1278           796.00           796.00      463.00         95000.00
#
# [1127 rows x 13 columns]

# %%
df.sort_values(by='engine(cc)')
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1494         Maruti                 No    Petrol      5       79862
# 1275        Hyundai                 No    Diesel      5       67000
# 174            Ford                Yes    Petrol      5       66717
# 1434     Volkswagen                Yes    Petrol      5       62920
# 1021       Mahindra                Yes    Petrol      6       18706
# ...             ...                ...       ...    ...         ...
# 920   Mercedes-Benz                Yes    Diesel      5       76000
# 917   Mercedes-Benz                 No    Diesel      7       46001
# 468   Mercedes-Benz                Yes    Diesel      7       19000
# 706   Mercedes-Benz                 No    Diesel      7       16000
# 1464  Mercedes-Benz                Yes    Diesel      7       34987
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  \
# 1494   First Owner       Manual               2010        1061.00
# 1275   First Owner       Manual               2015        1120.00
# 174   Second Owner       Manual               2011        1196.00
# 1434   First Owner       Manual               2017        1198.00
# 1021   First Owner       Manual               2018        1198.00
# ...            ...          ...                ...            ...
# 920    First Owner    Automatic               2015        2987.00
# 917    First Owner    Automatic               2021        2925.00
# 468   Second Owner    Automatic               2022        2925.00
# 706    First Owner    Automatic               2023        2925.00
# 1464   First Owner    Automatic               2020        2925.00
#
#            engine(cc)   max_power(bhp)  torque(Nm)  price(in lakhs)
# 1494            67.00            67.00       84.00             1.69
# 1275            70.00            70.00      160.00             4.25
# 174             70.00            70.00      102.00         70000.00
# 1434            74.00            74.00      110.00             5.27
# 1021            82.00            82.00      115.00             4.24
# ...               ...              ...         ...              ...
# 920     1652243800.00    1652243800.00      510.00            19.99
# 917  3258640000000.00 3258640000000.00      700.00             1.06
# 468  3258640000000.00 3258640000000.00      700.00             1.15
# 706  3258640000000.00 3258640000000.00      700.00             1.32
# 1464 3258640000000.00 3258640000000.00      700.00             1.10
#
# [1127 rows x 13 columns]

# %%
remove_extra=df[df['engine(cc)']>8000].index

# %%
df.drop(remove_extra,inplace=True)

# %%
df.describe()
# Out:
#         seats  kms_driven  mileage(kmpl)  engine(cc)  max_power(bhp)  \
# count 1072.00     1072.00        1072.00     1072.00         1072.00
# mean     5.18    53857.13         135.94     1627.16         1627.16
# std      0.60    43603.46         390.48     1004.20         1004.20
# min      4.00     1000.00           7.81       67.00           67.00
# 25%      5.00    30375.00          16.50     1197.00         1197.00
# 50%      5.00    49796.50          18.90     1384.00         1384.00
# 75%      5.00    70000.00          21.40     1956.00         1956.00
# max      8.00   810000.00        3996.00     7394.00         7394.00
#
#        torque(Nm)  price(in lakhs)
# count     1072.00          1072.00
# mean     13804.22           167.17
# std      87418.37          3601.99
# min         17.00             1.00
# 25%        739.00             4.52
# 50%       1213.00             6.75
# 75%       8873.00            13.90
# max    1186600.00         95000.00

# %%
df['price(in lakhs)']=df['price(in lakhs)'].replace(95000,0.95)
df['price(in lakhs)']=df['price(in lakhs)'].replace(70000,0.70)

# %%
df
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1109           Fiat                 No    Diesel      5       80000
# 1300        Porsche                 No    Petrol      5        5700
# 464   Mercedes-Benz                Yes    Petrol      4       40000
# 412            Land                 No    Petrol      5        4000
# 634            Audi                Yes    Petrol      5        7000
# ...             ...                ...       ...    ...         ...
# 480             BMW                Yes    Diesel      7       44000
# 221   Mercedes-Benz                Yes    Petrol      4       50000
# 1493            BMW                Yes    Petrol      7       28000
# 174            Ford                Yes    Petrol      5       66717
# 1278         Maruti                Yes    Petrol      5       44002
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1109   Third Owner       Manual               2010          20.30     1248.00
# 1300   First Owner    Automatic               2019        2995.00      340.00
# 464    First Owner    Automatic               2018           7.81     4663.00
# 412    First Owner    Automatic               2019          12.65     1997.00
# 634    First Owner    Automatic               2023           9.80     2995.00
# ...            ...          ...                ...            ...         ...
# 480    First Owner    Automatic               2020          13.38     2993.00
# 221    First Owner    Automatic               2016           7.81     4663.00
# 1493   First Owner    Automatic               2019          10.54     2998.00
# 174   Second Owner       Manual               2011        1196.00       70.00
# 1278   Third Owner       Manual               2009          19.70      796.00
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)
# 1109         1248.00       75.00             1.00
# 1300          340.00      450.00             1.05
# 464          4663.00      459.00             1.09
# 412          1997.00    29636.00             1.10
# 634          2995.00      340.00             1.12
# ...              ...         ...              ...
# 480          2993.00    26150.00            98.50
# 221          4663.00      459.00            98.50
# 1493         2998.00    33525.00            99.00
# 174            70.00      102.00             0.70
# 1278          796.00      463.00             0.95
#
# [1072 rows x 13 columns]

# %%
df.drop(columns='max_power(bhp)',inplace=True)

# %%
df
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1109           Fiat                 No    Diesel      5       80000
# 1300        Porsche                 No    Petrol      5        5700
# 464   Mercedes-Benz                Yes    Petrol      4       40000
# 412            Land                 No    Petrol      5        4000
# 634            Audi                Yes    Petrol      5        7000
# ...             ...                ...       ...    ...         ...
# 480             BMW                Yes    Diesel      7       44000
# 221   Mercedes-Benz                Yes    Petrol      4       50000
# 1493            BMW                Yes    Petrol      7       28000
# 174            Ford                Yes    Petrol      5       66717
# 1278         Maruti                Yes    Petrol      5       44002
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1109   Third Owner       Manual               2010          20.30     1248.00
# 1300   First Owner    Automatic               2019        2995.00      340.00
# 464    First Owner    Automatic               2018           7.81     4663.00
# 412    First Owner    Automatic               2019          12.65     1997.00
# 634    First Owner    Automatic               2023           9.80     2995.00
# ...            ...          ...                ...            ...         ...
# 480    First Owner    Automatic               2020          13.38     2993.00
# 221    First Owner    Automatic               2016           7.81     4663.00
# 1493   First Owner    Automatic               2019          10.54     2998.00
# 174   Second Owner       Manual               2011        1196.00       70.00
# 1278   Third Owner       Manual               2009          19.70      796.00
#
#       torque(Nm)  price(in lakhs)
# 1109       75.00             1.00
# 1300      450.00             1.05
# 464       459.00             1.09
# 412     29636.00             1.10
# 634       340.00             1.12
# ...          ...              ...
# 480     26150.00            98.50
# 221       459.00            98.50
# 1493    33525.00            99.00
# 174       102.00             0.70
# 1278      463.00             0.95
#
# [1072 rows x 12 columns]

# %%
df['manufacturing_year'].value_counts()
remove_cat=['Power Steering','Power Windows Front']

# %%
ac=df[df['manufacturing_year'].isin(remove_cat)].index

# %%
df.drop(ac,inplace=True)

# %%
df
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1109           Fiat                 No    Diesel      5       80000
# 1300        Porsche                 No    Petrol      5        5700
# 464   Mercedes-Benz                Yes    Petrol      4       40000
# 412            Land                 No    Petrol      5        4000
# 634            Audi                Yes    Petrol      5        7000
# ...             ...                ...       ...    ...         ...
# 480             BMW                Yes    Diesel      7       44000
# 221   Mercedes-Benz                Yes    Petrol      4       50000
# 1493            BMW                Yes    Petrol      7       28000
# 174            Ford                Yes    Petrol      5       66717
# 1278         Maruti                Yes    Petrol      5       44002
#
#         ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1109   Third Owner       Manual               2010          20.30     1248.00
# 1300   First Owner    Automatic               2019        2995.00      340.00
# 464    First Owner    Automatic               2018           7.81     4663.00
# 412    First Owner    Automatic               2019          12.65     1997.00
# 634    First Owner    Automatic               2023           9.80     2995.00
# ...            ...          ...                ...            ...         ...
# 480    First Owner    Automatic               2020          13.38     2993.00
# 221    First Owner    Automatic               2016           7.81     4663.00
# 1493   First Owner    Automatic               2019          10.54     2998.00
# 174   Second Owner       Manual               2011        1196.00       70.00
# 1278   Third Owner       Manual               2009          19.70      796.00
#
#       torque(Nm)  price(in lakhs)
# 1109       75.00             1.00
# 1300      450.00             1.05
# 464       459.00             1.09
# 412     29636.00             1.10
# 634       340.00             1.12
# ...          ...              ...
# 480     26150.00            98.50
# 221       459.00            98.50
# 1493    33525.00            99.00
# 174       102.00             0.70
# 1278      463.00             0.95
#
# [1055 rows x 12 columns]

# %%
df['current_year']=2024

# %%
df['car_age']=df['current_year']-df['manufacturing_year']

# %%
df.drop(columns=['current_year','manufacturing_year'],inplace=True)

# %%
df['ownsership'].value_counts()
# Out:
# ownsership
# First Owner     876
# Second Owner    161
# Third Owner      18
# Name: count, dtype: int64

# %%
df
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1109           Fiat                 No    Diesel      5       80000
# 1300        Porsche                 No    Petrol      5        5700
# 464   Mercedes-Benz                Yes    Petrol      4       40000
# 412            Land                 No    Petrol      5        4000
# 634            Audi                Yes    Petrol      5        7000
# ...             ...                ...       ...    ...         ...
# 480             BMW                Yes    Diesel      7       44000
# 221   Mercedes-Benz                Yes    Petrol      4       50000
# 1493            BMW                Yes    Petrol      7       28000
# 174            Ford                Yes    Petrol      5       66717
# 1278         Maruti                Yes    Petrol      5       44002
#
#         ownsership transmission  mileage(kmpl)  engine(cc)  torque(Nm)  \
# 1109   Third Owner       Manual          20.30     1248.00       75.00
# 1300   First Owner    Automatic        2995.00      340.00      450.00
# 464    First Owner    Automatic           7.81     4663.00      459.00
# 412    First Owner    Automatic          12.65     1997.00    29636.00
# 634    First Owner    Automatic           9.80     2995.00      340.00
# ...            ...          ...            ...         ...         ...
# 480    First Owner    Automatic          13.38     2993.00    26150.00
# 221    First Owner    Automatic           7.81     4663.00      459.00
# 1493   First Owner    Automatic          10.54     2998.00    33525.00
# 174   Second Owner       Manual        1196.00       70.00      102.00
# 1278   Third Owner       Manual          19.70      796.00      463.00
#
#       price(in lakhs) car_age
# 1109             1.00      14
# 1300             1.05       5
# 464              1.09       6
# 412              1.10       5
# 634              1.12       1
# ...               ...     ...
# 480             98.50       4
# 221             98.50       8
# 1493            99.00       5
# 174              0.70      13
# 1278             0.95      15
#
# [1055 rows x 12 columns]

# %%
df.describe()
# Out:
#         seats  kms_driven  mileage(kmpl)  engine(cc)  torque(Nm)  \
# count 1055.00     1055.00        1055.00     1055.00     1055.00
# mean     5.18    53968.92         114.03     1634.13    14022.70
# std      0.61    43778.72         347.04      974.43    88103.44
# min      4.00     1000.00           7.81       67.00       19.00
# 25%      5.00    30483.00          16.47     1197.00      789.00
# 50%      5.00    50000.00          18.80     1396.00     1262.00
# 75%      5.00    70000.00          21.40     1956.00     8876.00
# max      8.00   810000.00        3996.00     7394.00  1186600.00
#
#        price(in lakhs)
# count          1055.00
# mean             13.26
# std              16.42
# min               0.70
# 25%               4.50
# 50%               6.70
# 75%              13.54
# max              99.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1055 entries, 1109 to 1278
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1055 non-null   object
#  1   insurance_validity  1055 non-null   object
#  2   fuel_type           1055 non-null   object
#  3   seats               1055 non-null   int64
#  4   kms_driven          1055 non-null   int64
#  5   ownsership          1055 non-null   object
#  6   transmission        1055 non-null   object
#  7   mileage(kmpl)       1055 non-null   float64
#  8   engine(cc)          1055 non-null   float64
#  9   torque(Nm)          1055 non-null   float64
#  10  price(in lakhs)     1055 non-null   float64
#  11  car_age             1055 non-null   object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 103.0+ KB

# %%
df['car_age']=df['car_age'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1055 entries, 1109 to 1278
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1055 non-null   object
#  1   insurance_validity  1055 non-null   object
#  2   fuel_type           1055 non-null   object
#  3   seats               1055 non-null   int64
#  4   kms_driven          1055 non-null   int64
#  5   ownsership          1055 non-null   object
#  6   transmission        1055 non-null   object
#  7   mileage(kmpl)       1055 non-null   float64
#  8   engine(cc)          1055 non-null   float64
#  9   torque(Nm)          1055 non-null   float64
#  10  price(in lakhs)     1055 non-null   float64
#  11  car_age             1055 non-null   int32
# dtypes: float64(4), int32(1), int64(2), object(5)
# memory usage: 98.9+ KB

# %%
df.describe()
# Out:
#         seats  kms_driven  mileage(kmpl)  engine(cc)  torque(Nm)  \
# count 1055.00     1055.00        1055.00     1055.00     1055.00
# mean     5.18    53968.92         114.03     1634.13    14022.70
# std      0.61    43778.72         347.04      974.43    88103.44
# min      4.00     1000.00           7.81       67.00       19.00
# 25%      5.00    30483.00          16.47     1197.00      789.00
# 50%      5.00    50000.00          18.80     1396.00     1262.00
# 75%      5.00    70000.00          21.40     1956.00     8876.00
# max      8.00   810000.00        3996.00     7394.00  1186600.00
#
#        price(in lakhs)  car_age
# count          1055.00  1055.00
# mean             13.26     6.77
# std              16.42     2.95
# min               0.70     1.00
# 25%               4.50     5.00
# 50%               6.70     6.00
# 75%              13.54     9.00
# max              99.00    17.00

# %%
df.drop(columns='torque(Nm)',inplace=True)

# %%
df
# Out:
#            car_name insurance_validity fuel_type  seats  kms_driven  \
# 1109           Fiat                 No    Diesel      5       80000
# 1300        Porsche                 No    Petrol      5        5700
# 464   Mercedes-Benz                Yes    Petrol      4       40000
# 412            Land                 No    Petrol      5        4000
# 634            Audi                Yes    Petrol      5        7000
# ...             ...                ...       ...    ...         ...
# 480             BMW                Yes    Diesel      7       44000
# 221   Mercedes-Benz                Yes    Petrol      4       50000
# 1493            BMW                Yes    Petrol      7       28000
# 174            Ford                Yes    Petrol      5       66717
# 1278         Maruti                Yes    Petrol      5       44002
#
#         ownsership transmission  mileage(kmpl)  engine(cc)  price(in lakhs)  \
# 1109   Third Owner       Manual          20.30     1248.00             1.00
# 1300   First Owner    Automatic        2995.00      340.00             1.05
# 464    First Owner    Automatic           7.81     4663.00             1.09
# 412    First Owner    Automatic          12.65     1997.00             1.10
# 634    First Owner    Automatic           9.80     2995.00             1.12
# ...            ...          ...            ...         ...              ...
# 480    First Owner    Automatic          13.38     2993.00            98.50
# 221    First Owner    Automatic           7.81     4663.00            98.50
# 1493   First Owner    Automatic          10.54     2998.00            99.00
# 174   Second Owner       Manual        1196.00       70.00             0.70
# 1278   Third Owner       Manual          19.70      796.00             0.95
#
#       car_age
# 1109       14
# 1300        5
# 464         6
# 412         5
# 634         1
# ...       ...
# 480         4
# 221         8
# 1493        5
# 174        13
# 1278       15
#
# [1055 rows x 11 columns]

# %%
df.describe()
# Out:
#         seats  kms_driven  mileage(kmpl)  engine(cc)  price(in lakhs)  car_age
# count 1055.00     1055.00        1055.00     1055.00          1055.00  1055.00
# mean     5.18    53968.92         114.03     1634.13            13.26     6.77
# std      0.61    43778.72         347.04      974.43            16.42     2.95
# min      4.00     1000.00           7.81       67.00             0.70     1.00
# 25%      5.00    30483.00          16.47     1197.00             4.50     5.00
# 50%      5.00    50000.00          18.80     1396.00             6.70     6.00
# 75%      5.00    70000.00          21.40     1956.00            13.54     9.00
# max      8.00   810000.00        3996.00     7394.00            99.00    17.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1055 entries, 1109 to 1278
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            1055 non-null   object
#  1   insurance_validity  1055 non-null   object
#  2   fuel_type           1055 non-null   object
#  3   seats               1055 non-null   int64
#  4   kms_driven          1055 non-null   int64
#  5   ownsership          1055 non-null   object
#  6   transmission        1055 non-null   object
#  7   mileage(kmpl)       1055 non-null   float64
#  8   engine(cc)          1055 non-null   float64
#  9   price(in lakhs)     1055 non-null   float64
#  10  car_age             1055 non-null   int32
# dtypes: float64(3), int32(1), int64(2), object(5)
# memory usage: 90.7+ KB

# %%
remove_mileage=df[df['mileage(kmpl)']>70].index

# %%
df.drop(remove_mileage,inplace=True)

# %%
df.index=np.arange(1,len(df)+1)

# %%
df
# Out:
#           car_name insurance_validity fuel_type  seats  kms_driven  \
# 1             Fiat                 No    Diesel      5       80000
# 2    Mercedes-Benz                Yes    Petrol      4       40000
# 3             Land                 No    Petrol      5        4000
# 4             Audi                Yes    Petrol      5        7000
# 5              BMW                 No    Petrol      7        7000
# ..             ...                ...       ...    ...         ...
# 965  Mercedes-Benz                 No    Diesel      5       18346
# 966            BMW                Yes    Diesel      7       44000
# 967  Mercedes-Benz                Yes    Petrol      4       50000
# 968            BMW                Yes    Petrol      7       28000
# 969         Maruti                Yes    Petrol      5       44002
#
#       ownsership transmission  mileage(kmpl)  engine(cc)  price(in lakhs)  \
# 1    Third Owner       Manual          20.30     1248.00             1.00
# 2    First Owner    Automatic           7.81     4663.00             1.09
# 3    First Owner    Automatic          12.65     1997.00             1.10
# 4    First Owner    Automatic           9.80     2995.00             1.12
# 5    First Owner    Automatic          10.54     2998.00             1.15
# ..           ...          ...            ...         ...              ...
# 965  First Owner    Automatic          13.50     2925.00            97.00
# 966  First Owner    Automatic          13.38     2993.00            98.50
# 967  First Owner    Automatic           7.81     4663.00            98.50
# 968  First Owner    Automatic          10.54     2998.00            99.00
# 969  Third Owner       Manual          19.70      796.00             0.95
#
#      car_age
# 1         14
# 2          6
# 3          5
# 4          1
# 5          3
# ..       ...
# 965        4
# 966        4
# 967        8
# 968        5
# 969       15
#
# [969 rows x 11 columns]

# %%
 df.describe()
# Out:
#        seats  kms_driven  mileage(kmpl)  engine(cc)  price(in lakhs)  car_age
# count 969.00      969.00         969.00      969.00           969.00   969.00
# mean    5.19    54438.11          18.28     1588.95            13.90     6.62
# std     0.62    45063.50           3.75      583.87            16.77     2.85
# min     4.00     1000.00           7.81      796.00             0.95     1.00
# 25%     5.00    31000.00          16.10     1197.00             4.90     5.00
# 50%     5.00    50000.00          18.53     1461.00             6.95     6.00
# 75%     5.00    70000.00          20.70     1956.00            14.75     8.00
# max     8.00   810000.00          28.40     5461.00            99.00    17.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_num=df[['seats','kms_driven','mileage(kmpl)','engine(cc)','price(in lakhs)','car_age']]

# %%
sns.pairplot(df_num)
# Out:
# C:\Users\bittu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bittu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bittu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bittu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bittu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\bittu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(x=df['car_name'],y=df['price(in lakhs)'])
plt.figure(figsize=(200,20))

# %%
sns.histplot(df.car_name)
# Out:
# C:\Users\bittu\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='car_name', ylabel='Count'>

# %%
sns.boxplot(y=df['kms_driven'],hue=df['fuel_type'])
# Out:
# <Axes: ylabel='kms_driven'>

# %%
remove_kms_outlier=df[df['kms_driven']>400000].index

# %%
df.drop(remove_kms_outlier,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 967 entries, 1 to 969
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   car_name            967 non-null    object
#  1   insurance_validity  967 non-null    object
#  2   fuel_type           967 non-null    object
#  3   seats               967 non-null    int64
#  4   kms_driven          967 non-null    int64
#  5   ownsership          967 non-null    object
#  6   transmission        967 non-null    object
#  7   mileage(kmpl)       967 non-null    float64
#  8   engine(cc)          967 non-null    float64
#  9   price(in lakhs)     967 non-null    float64
#  10  car_age             967 non-null    int32
# dtypes: float64(3), int32(1), int64(2), object(5)
# memory usage: 83.1+ KB

# %%
dfcopy1=df

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
le.fit_transform(df['car_name'])
for car_name,label in zip(le.classes_,le.transform(le.classes_)):
    print(f" Car Name : {car_name} , label : {label} ")
# Out:
#  Car Name : Audi , label : 0
#  Car Name : BMW , label : 1
#  Car Name : Datsun , label : 2
#  Car Name : Fiat , label : 3
#  Car Name : Ford , label : 4
#  Car Name : Honda , label : 5
#  Car Name : Hyundai , label : 6
#  Car Name : Isuzu , label : 7
#  Car Name : Jaguar , label : 8
#  Car Name : Jeep , label : 9
#  Car Name : Kia , label : 10
#  Car Name : Land , label : 11
#  Car Name : MG , label : 12
#  Car Name : Mahindra , label : 13
#  Car Name : Maruti , label : 14
#  Car Name : Mercedes-Benz , label : 15
#  Car Name : Mini , label : 16
#  Car Name : Mitsubishi , label : 17
#  Car Name : Nexus , label : 18
#  Car Name : Nissan , label : 19
#  Car Name : Porsche , label : 20
#  Car Name : Renault , label : 21
#  Car Name : Skoda , label : 22
#  Car Name : Tata , label : 23
#  Car Name : Toyota , label : 24
#  Car Name : Volkswagen , label : 25
#  Car Name : Volvo , label : 26

# %%
df
# Out:
#           car_name insurance_validity fuel_type  seats  kms_driven  \
# 1             Fiat                 No    Diesel      5       80000
# 2    Mercedes-Benz                Yes    Petrol      4       40000
# 3             Land                 No    Petrol      5        4000
# 4             Audi                Yes    Petrol      5        7000
# 5              BMW                 No    Petrol      7        7000
# ..             ...                ...       ...    ...         ...
# 965  Mercedes-Benz                 No    Diesel      5       18346
# 966            BMW                Yes    Diesel      7       44000
# 967  Mercedes-Benz                Yes    Petrol      4       50000
# 968            BMW                Yes    Petrol      7       28000
# 969         Maruti                Yes    Petrol      5       44002
#
#       ownsership transmission  mileage(kmpl)  engine(cc)  price(in lakhs)  \
# 1    Third Owner       Manual          20.30     1248.00             1.00
# 2    First Owner    Automatic           7.81     4663.00             1.09
# 3    First Owner    Automatic          12.65     1997.00             1.10
# 4    First Owner    Automatic           9.80     2995.00             1.12
# 5    First Owner    Automatic          10.54     2998.00             1.15
# ..           ...          ...            ...         ...              ...
# 965  First Owner    Automatic          13.50     2925.00            97.00
# 966  First Owner    Automatic          13.38     2993.00            98.50
# 967  First Owner    Automatic           7.81     4663.00            98.50
# 968  First Owner    Automatic          10.54     2998.00            99.00
# 969  Third Owner       Manual          19.70      796.00             0.95
#
#      car_age
# 1         14
# 2          6
# 3          5
# 4          1
# 5          3
# ..       ...
# 965        4
# 966        4
# 967        8
# 968        5
# 969       15
#
# [967 rows x 11 columns]

# %%
df['car_name']=le.fit_transform(df['car_name'])

# %%
for car_name,label in zip(le.classes_,le.transform(le.classes_)):
    print(f" Car Name : {car_name} , label : {label} ")
# Out:
#  Car Name : Audi , label : 0
#  Car Name : BMW , label : 1
#  Car Name : Datsun , label : 2
#  Car Name : Fiat , label : 3
#  Car Name : Ford , label : 4
#  Car Name : Honda , label : 5
#  Car Name : Hyundai , label : 6
#  Car Name : Isuzu , label : 7
#  Car Name : Jaguar , label : 8
#  Car Name : Jeep , label : 9
#  Car Name : Kia , label : 10
#  Car Name : Land , label : 11
#  Car Name : MG , label : 12
#  Car Name : Mahindra , label : 13
#  Car Name : Maruti , label : 14
#  Car Name : Mercedes-Benz , label : 15
#  Car Name : Mini , label : 16
#  Car Name : Mitsubishi , label : 17
#  Car Name : Nexus , label : 18
#  Car Name : Nissan , label : 19
#  Car Name : Porsche , label : 20
#  Car Name : Renault , label : 21
#  Car Name : Skoda , label : 22
#  Car Name : Tata , label : 23
#  Car Name : Toyota , label : 24
#  Car Name : Volkswagen , label : 25
#  Car Name : Volvo , label : 26

# %%
df
# Out:
#      car_name insurance_validity fuel_type  seats  kms_driven   ownsership  \
# 1           3                 No    Diesel      5       80000  Third Owner
# 2          15                Yes    Petrol      4       40000  First Owner
# 3          11                 No    Petrol      5        4000  First Owner
# 4           0                Yes    Petrol      5        7000  First Owner
# 5           1                 No    Petrol      7        7000  First Owner
# ..        ...                ...       ...    ...         ...          ...
# 965        15                 No    Diesel      5       18346  First Owner
# 966         1                Yes    Diesel      7       44000  First Owner
# 967        15                Yes    Petrol      4       50000  First Owner
# 968         1                Yes    Petrol      7       28000  First Owner
# 969        14                Yes    Petrol      5       44002  Third Owner
#
#     transmission  mileage(kmpl)  engine(cc)  price(in lakhs)  car_age
# 1         Manual          20.30     1248.00             1.00       14
# 2      Automatic           7.81     4663.00             1.09        6
# 3      Automatic          12.65     1997.00             1.10        5
# 4      Automatic           9.80     2995.00             1.12        1
# 5      Automatic          10.54     2998.00             1.15        3
# ..           ...            ...         ...              ...      ...
# 965    Automatic          13.50     2925.00            97.00        4
# 966    Automatic          13.38     2993.00            98.50        4
# 967    Automatic           7.81     4663.00            98.50        8
# 968    Automatic          10.54     2998.00            99.00        5
# 969       Manual          19.70      796.00             0.95       15
#
# [967 rows x 11 columns]

# %%
df['insurance_validity']=le.fit_transform(df['insurance_validity'])

# %%
for insurance_validity,label in zip(le.classes_,le.transform(le.classes_)):
    print(f" Insurance : {insurance_validity} , label : {label} ")
# Out:
#  Insurance : No , label : 0
#  Insurance : Yes , label : 1

# %%
df['fuel_type']=le.fit_transform(df['fuel_type'])

# %%
for fuel_type,label in zip(le.classes_,le.transform(le.classes_)):
    print(f" Fuel Type: {fuel_type},Label:{label}")
# Out:
#  Fuel Type: CNG,Label:0
#  Fuel Type: Diesel,Label:1
#  Fuel Type: Petrol,Label:2

# %%
df['transmission']=le.fit_transform(df['transmission'])

# %%
for transmission,label in zip(le.classes_,le.transform(le.classes_)):
    print(f" Transmission :{transmission}, Label : {label}")
# Out:
#  Transmission :Automatic, Label : 0
#  Transmission :Manual, Label : 1

# %%
 df['ownsership'].unique()
# Out:
# array(['Third Owner', 'First Owner', 'Second Owner'], dtype=object)

# %%
df['ownsership']=df['ownsership'].replace('First Owner',1)
df['ownsership']=df['ownsership'].replace('Second Owner',2)
df['ownsership']=df['ownsership'].replace('Third Owner',3)

# %%
df
# Out:
#      car_name  insurance_validity  fuel_type  seats  kms_driven  ownsership  \
# 1           3                   0          1      5       80000           3
# 2          15                   1          2      4       40000           1
# 3          11                   0          2      5        4000           1
# 4           0                   1          2      5        7000           1
# 5           1                   0          2      7        7000           1
# ..        ...                 ...        ...    ...         ...         ...
# 965        15                   0          1      5       18346           1
# 966         1                   1          1      7       44000           1
# 967        15                   1          2      4       50000           1
# 968         1                   1          2      7       28000           1
# 969        14                   1          2      5       44002           3
#
#      transmission  mileage(kmpl)  engine(cc)  price(in lakhs)  car_age
# 1               1          20.30     1248.00             1.00       14
# 2               0           7.81     4663.00             1.09        6
# 3               0          12.65     1997.00             1.10        5
# 4               0           9.80     2995.00             1.12        1
# 5               0          10.54     2998.00             1.15        3
# ..            ...            ...         ...              ...      ...
# 965             0          13.50     2925.00            97.00        4
# 966             0          13.38     2993.00            98.50        4
# 967             0           7.81     4663.00            98.50        8
# 968             0          10.54     2998.00            99.00        5
# 969             1          19.70      796.00             0.95       15
#
# [967 rows x 11 columns]

# %%
df.corr()
# Out:
#                     car_name  insurance_validity  fuel_type  seats  \
# car_name                1.00                0.03      -0.03   0.11
# insurance_validity      0.03                1.00       0.06  -0.06
# fuel_type              -0.03                0.06       1.00  -0.32
# seats                   0.11               -0.06      -0.32   1.00
# kms_driven             -0.01               -0.06      -0.24   0.12
# ownsership             -0.06               -0.14      -0.10   0.04
# transmission            0.05                0.06       0.15  -0.08
# mileage(kmpl)           0.00                0.05      -0.13  -0.27
# engine(cc)              0.01               -0.07      -0.37   0.33
# price(in lakhs)        -0.06               -0.07      -0.18   0.16
# car_age                -0.11               -0.02      -0.03  -0.05
#
#                     kms_driven  ownsership  transmission  mileage(kmpl)  \
# car_name                 -0.01       -0.06          0.05           0.00
# insurance_validity       -0.06       -0.14          0.06           0.05
# fuel_type                -0.24       -0.10          0.15          -0.13
# seats                     0.12        0.04         -0.08          -0.27
# kms_driven                1.00        0.15          0.15           0.07
# ownsership                0.15        1.00         -0.05          -0.06
# transmission              0.15       -0.05          1.00           0.49
# mileage(kmpl)             0.07       -0.06          0.49           1.00
# engine(cc)                0.03        0.09         -0.53          -0.64
# price(in lakhs)          -0.25        0.01         -0.54          -0.48
# car_age                   0.54        0.25          0.24           0.05
#
#                     engine(cc)  price(in lakhs)  car_age
# car_name                  0.01            -0.06    -0.11
# insurance_validity       -0.07            -0.07    -0.02
# fuel_type                -0.37            -0.18    -0.03
# seats                     0.33             0.16    -0.05
# kms_driven                0.03            -0.25     0.54
# ownsership                0.09             0.01     0.25
# transmission             -0.53            -0.54     0.24
# mileage(kmpl)            -0.64            -0.48     0.05
# engine(cc)                1.00             0.64    -0.07
# price(in lakhs)           0.64             1.00    -0.32
# car_age                  -0.07            -0.32     1.00

# %%
X=df.drop(columns='price(in lakhs)')

# %%
y=df['price(in lakhs)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5839663671572933

# %%
import joblib

# %%
joblib.dump(model,'carspred.pkl')
# Out:
# ['carspred.pkl']
